# %%
import csv, os, glob
import numpy as np
import tensorflow as tf
import features as features_lib
import tensorflow as tf
import yamnet_short

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
parent_dir = "D:\\datasets\\UrbanSounds8K\\resampled_wav_16000"
folds = np.array(['fold1','fold2','fold3','fold4',
                  'fold5','fold6','fold7','fold8',
                  'fold9','fold10'])
classes = ['0_air_conditioner', '1_car_horn', '2_children_playing', '3_dog_bark', 
'4_drilling', '5_engine_idling', '6_gun_shot', '7_jackhammer', '8_siren', '9_street_music']

from sklearn.model_selection import KFold

kf = KFold(n_splits=10)
def filenames_train_test(parent_dir, folds):
    for i, (train_index, test_index) in enumerate(kf.split(folds)):
        filenames_train, filenames_test = [],[]
        # print(folds[train_index], folds[test_index])
        for fold in folds[train_index]:
            filenames = glob.glob(os.path.join(parent_dir, fold, "*.wav"))
            filenames_train.extend(filenames)
        for fold in folds[test_index]:
            filenames = glob.glob(os.path.join(parent_dir, fold, "*.wav"))
            filenames_test.extend(filenames)
        yield (filenames_train, filenames_test)

for (x,y) in filenames_train_test(parent_dir, folds):
    print(len(x), len(y))
# Out:
# 7859 873
# 7844 888
# 7807 925
# 7742 990
# 7796 936
# 7909 823
# 7894 838
# 7926 806
# 7916 816
# 7895 837

# %%
from audiomentations import Compose, AddGaussianNoise, TimeStretch, PitchShift, Shift
import numpy as np

augment = Compose([
    AddGaussianNoise(min_amplitude=0.001, max_amplitude=0.015, p=0.5),
    TimeStretch(min_rate=0.8, max_rate=1.25, p=0.5),
    PitchShift(min_semitones=-4, max_semitones=4, p=0.5),
    # Shift(min_fraction=-0.5, max_fraction=0.5, p=0.5),
    # AddBackgroundNoise
    # AddShortNoises
])

# @tf.function
def augment_sample(augment, wave):
    wave = augment(samples=wave, sample_rate=16000)  
    return wave

import params as yamnet_params
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(contents=audio_binary)
  return tf.squeeze(audio, axis=-1)
  
def get_label(filename):
    label = tf.strings.split(filename, "\\")[-1]
    label = tf.strings.split(label, "-")[1]
    length = len(get_embedding(filename))
    try: 
      label = tf.repeat(label, length)
    except:
      pass
    label = tf.cast(int(label), dtype='int32')
    return label

def get_waveform_no_label(file_path):
  audio_binary = tf.io.read_file(file_path)
  waveform = decode_audio(audio_binary)
  waveform = tf.cast(waveform, dtype=tf.float32)
  return waveform

@tf.function
def get_embedding(filename, AUGMENT=False):
  params = yamnet_params.Params(sample_rate=16000, patch_hop_seconds=0.5)
  waveform = get_waveform_no_label(filename)
  if AUGMENT==True:
    waveform = augment_sample(augment, waveform)
  waveform_padded = features_lib.pad_waveform(waveform, params)
  log_mel_spectrogram, features = features_lib.waveform_to_log_mel_spectrogram_patches(
      waveform_padded, params)
  return tf.expand_dims(features, axis=-1)
  # return log_mel_spectrogram

# %%
# Create a dataset of filenames
def get_dataset(filenames, augment_flag=False, training=True):
  dataset = tf.data.Dataset.from_tensor_slices(filenames)
  # Map the filenames to the embeddings
  dataset_samples_noaugment = dataset.map(
    map_func = lambda x: tf.py_function(get_embedding, inp=[x, augment_flag], Tout=tf.float32, name=None),
    num_parallel_calls=tf.data.AUTOTUNE
  )
  dataset_samples_augment = dataset.map(
    map_func = lambda x: tf.py_function(get_embedding, inp=[x, augment_flag], Tout=tf.float32, name=None),
    num_parallel_calls=tf.data.AUTOTUNE
  )
  dataset_samples_combined = dataset_samples_noaugment.concatenate(dataset_samples_augment)
  dataset_labels = dataset.map(get_label)
  dataset_labels_combined = dataset_labels.concatenate(dataset_labels)

  if training==True:
    # Flatmap the embeddings to squeeze dim=0 and then zip the samples and labels
    dataset_samples_combined = dataset_samples_combined.flat_map(lambda x: tf.data.Dataset.from_tensor_slices(x))
    dataset_labels_combined = dataset_labels_combined.flat_map(lambda x: tf.data.Dataset.from_tensor_slices(x))

  dataset = dataset.zip((dataset_samples_combined, dataset_labels_combined))
  return dataset

# %%
import datetime

for i, (filenames_train, filenames_test) in enumerate(filenames_train_test(parent_dir, folds)):  
    AUTOTUNE = tf.data.AUTOTUNE
    random.shuffle(filenames_train)
    length = len(filenames_train)
    train_dataset = get_dataset(filenames_train[:int(length*0.75)], augment_flag=True, training=True)
    eval_dataset = get_dataset(filenames_train[int(length*0.75):], augment_flag=True, training=True)
    train_dataset = train_dataset.batch(64).cache().prefetch(AUTOTUNE)
    eval_dataset = eval_dataset.batch(64).cache().prefetch(AUTOTUNE)
        
    # print("Length of train, eval, test datasets:", len(list(train_dataset)),len(list(eval_dataset)),len(list(test_dataset)))
    
    # Paths
    training_path = "./training/{}".format(datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
    ckp_path = training_path + "/fold{}/checkpoints/cp.ckpt".format(i+1)
    log_path = training_path + "/fold{}/logs/fit".format(i+1)       
    hd5_path = training_path + "/fold{}/model.hd5".format(i+1)
    cfm_path = training_path + "/fold{}/confusion_matrix.png".format(i+1)
    
    # Create a callback that saves the model's weights
    cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=ckp_path,
                                                    save_weights_only=True,
                                                    verbose=1)
    # Create a tensorboard callback                         
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_path, histogram_freq=1)
    
    # Declare model
    Yamnet_Short = yamnet_short.Yamnet_short()
    yamnet_model = Yamnet_Short.model()
    yamnet_model.compile(
        optimizer=tf.keras.optimizers.Adam(),
        loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=['accuracy'],
    )
    # yamnet_model.summary()

    # Fit model
    yamnet_model.fit(train_dataset, validation_data = eval_dataset, epochs=10, 
        verbose=1, callbacks=[cp_callback,tensorboard_callback])

    # Save HD5 model from final epoch 
    yamnet_model.save(hd5_path)
    # new_model = tf.keras.models.load_model('my_model.h5')

    # Evaluate performance of model with test fold (that it wasn't trained on)
    test_dataset = get_dataset(filenames_test, augment_flag=False, training=False).cache().prefetch(AUTOTUNE)
    yamnet_model.load_weights(ckp_path)
    loss, acc = yamnet_model.evaluate(test_dataset, verbose=2)
    # print(acc)

    # test_samples = test_dataset.map(lambda x,y: x)
    # test_labels = test_dataset.map(lambda x,y: y[0])

    # # Get y_preds = predictions made by model
    # y_preds = []
    # for x in test_samples:
    #     y_pred = tf.argmax(tf.math.reduce_sum(yamnet_model.predict(x), axis=0))
    #     y_preds.append(y_pred)

    # y_preds = np.array(y_preds)

    # # Get y_true = actual labels
    # def get_numpy(a_list):
    #     for b in a_list:
    #         yield b.numpy()

    # y_true = np.array([b for b in get_numpy(list(test_labels))])
    # accuracy = accuracy_score(y_true, y_preds)
    # print("Testing accuracy: ", accuracy)
    # cm = ConfusionMatrixDisplay.from_predictions(y_true, y_preds)
    # cm.figure_.savefig(cfm_path,dpi=500)
# Out:
# Epoch 1/10
#    1318/Unknown - 96s 67ms/step - loss: 1.0774 - accuracy: 0.6326
# Epoch 1: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 113s 80ms/step - loss: 1.0773 - accuracy: 0.6326 - val_loss: 0.5970 - val_accuracy: 0.8042
# Epoch 2/10
# 1319/1319 [==============================] - ETA: 0s - loss: 0.5118 - accuracy: 0.8293
# Epoch 2: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.5118 - accuracy: 0.8293 - val_loss: 0.4227 - val_accuracy: 0.8628
# Epoch 3/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.2972 - accuracy: 0.9028
# Epoch 3: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.2972 - accuracy: 0.9028 - val_loss: 0.4083 - val_accuracy: 0.8750
# Epoch 4/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.1863 - accuracy: 0.9397
# Epoch 4: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.1863 - accuracy: 0.9397 - val_loss: 0.4459 - val_accuracy: 0.8637
# Epoch 5/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.1529 - accuracy: 0.9488
# Epoch 5: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.1529 - accuracy: 0.9488 - val_loss: 0.3953 - val_accuracy: 0.8861
# Epoch 6/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9728
# Epoch 6: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 65s 49ms/step - loss: 0.0845 - accuracy: 0.9728 - val_loss: 0.3763 - val_accuracy: 0.9043
# Epoch 7/10
# 1319/1319 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9679
# Epoch 7: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 65s 49ms/step - loss: 0.0952 - accuracy: 0.9679 - val_loss: 0.3696 - val_accuracy: 0.9068
# Epoch 8/10
# 1319/1319 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9844
# Epoch 8: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.0495 - accuracy: 0.9844 - val_loss: 0.4948 - val_accuracy: 0.8941
# Epoch 9/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.0737 - accuracy: 0.9755
# Epoch 9: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.0737 - accuracy: 0.9755 - val_loss: 0.4066 - val_accuracy: 0.9089
# Epoch 10/10
# 1319/1319 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9805
# Epoch 10: saving model to ./training/20220406-161221/fold1/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 66s 50ms/step - loss: 0.0570 - accuracy: 0.9805 - val_loss: 0.4175 - val_accuracy: 0.9053
# INFO:tensorflow:Assets written to: ./training/20220406-161221/fold1/model.hd5\assets
# 1746/1746 - 14s - loss: 3.4339 - accuracy: 0.5337 - 14s/epoch - 8ms/step
# Epoch 1/10
#    1319/Unknown - 92s 66ms/step - loss: 1.1010 - accuracy: 0.6221
# Epoch 1: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 110s 79ms/step - loss: 1.1010 - accuracy: 0.6221 - val_loss: 0.7613 - val_accuracy: 0.7535
# Epoch 2/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.5159 - accuracy: 0.8296
# Epoch 2: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.5163 - accuracy: 0.8294 - val_loss: 0.7338 - val_accuracy: 0.7620
# Epoch 3/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.3161 - accuracy: 0.8944
# Epoch 3: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 48ms/step - loss: 0.3164 - accuracy: 0.8943 - val_loss: 0.5025 - val_accuracy: 0.8344
# Epoch 4/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.1997 - accuracy: 0.9330
# Epoch 4: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.2000 - accuracy: 0.9329 - val_loss: 0.5731 - val_accuracy: 0.8309
# Epoch 5/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.1386 - accuracy: 0.9539
# Epoch 5: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.1391 - accuracy: 0.9538 - val_loss: 0.4343 - val_accuracy: 0.8771
# Epoch 6/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.1071 - accuracy: 0.9647
# Epoch 6: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.1078 - accuracy: 0.9646 - val_loss: 0.5158 - val_accuracy: 0.8710
# Epoch 7/10
# 1319/1319 [==============================] - ETA: 0s - loss: 0.0978 - accuracy: 0.9672
# Epoch 7: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.0978 - accuracy: 0.9672 - val_loss: 0.3563 - val_accuracy: 0.9046
# Epoch 8/10
# 1319/1319 [==============================] - ETA: 0s - loss: 0.0689 - accuracy: 0.9774
# Epoch 8: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.0689 - accuracy: 0.9774 - val_loss: 0.4665 - val_accuracy: 0.8908
# Epoch 9/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.0623 - accuracy: 0.9784
# Epoch 9: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.0626 - accuracy: 0.9783 - val_loss: 0.3510 - val_accuracy: 0.9125
# Epoch 10/10
# 1318/1319 [============================>.] - ETA: 0s - loss: 0.0535 - accuracy: 0.9817
# Epoch 10: saving model to ./training/20220406-162445/fold2/checkpoints\cp.ckpt
# 1319/1319 [==============================] - 64s 49ms/step - loss: 0.0536 - accuracy: 0.9817 - val_loss: 0.4258 - val_accuracy: 0.8973
# INFO:tensorflow:Assets written to: ./training/20220406-162445/fold2/model.hd5\assets
# 1776/1776 - 13s - loss: 3.2601 - accuracy: 0.5917 - 13s/epoch - 7ms/step
# Epoch 1/10
#    1310/Unknown - 96s 70ms/step - loss: 1.0675 - accuracy: 0.6342
# Epoch 1: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 115s 84ms/step - loss: 1.0675 - accuracy: 0.6342 - val_loss: 0.8252 - val_accuracy: 0.7424
# Epoch 2/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.5169 - accuracy: 0.8305
# Epoch 2: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.5169 - accuracy: 0.8305 - val_loss: 0.5218 - val_accuracy: 0.8385
# Epoch 3/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.3151 - accuracy: 0.8961
# Epoch 3: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.3151 - accuracy: 0.8961 - val_loss: 0.6617 - val_accuracy: 0.8118
# Epoch 4/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.2013 - accuracy: 0.9345
# Epoch 4: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.2014 - accuracy: 0.9345 - val_loss: 0.4004 - val_accuracy: 0.8838
# Epoch 5/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9515
# Epoch 5: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.1451 - accuracy: 0.9515 - val_loss: 0.4144 - val_accuracy: 0.8896
# Epoch 6/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.1173 - accuracy: 0.9613
# Epoch 6: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 63s 48ms/step - loss: 0.1173 - accuracy: 0.9614 - val_loss: 0.4618 - val_accuracy: 0.8875
# Epoch 7/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.0865 - accuracy: 0.9708
# Epoch 7: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.0865 - accuracy: 0.9708 - val_loss: 0.4852 - val_accuracy: 0.8868
# Epoch 8/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.0907 - accuracy: 0.9688
# Epoch 8: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.0907 - accuracy: 0.9688 - val_loss: 0.5886 - val_accuracy: 0.8685
# Epoch 9/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.0502 - accuracy: 0.9832
# Epoch 9: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.0502 - accuracy: 0.9832 - val_loss: 0.4216 - val_accuracy: 0.9073
# Epoch 10/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.0685 - accuracy: 0.9762
# Epoch 10: saving model to ./training/20220406-163650/fold3/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 65s 49ms/step - loss: 0.0685 - accuracy: 0.9762 - val_loss: 0.6656 - val_accuracy: 0.8647
# INFO:tensorflow:Assets written to: ./training/20220406-163650/fold3/model.hd5\assets
# 1850/1850 - 17s - loss: 5.3350 - accuracy: 0.4627 - 17s/epoch - 9ms/step
# Epoch 1/10
#    1302/Unknown - 92s 66ms/step - loss: 1.1034 - accuracy: 0.6240
# Epoch 1: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 108s 79ms/step - loss: 1.1034 - accuracy: 0.6240 - val_loss: 0.6262 - val_accuracy: 0.7959
# Epoch 2/10
# 1302/1302 [==============================] - ETA: 0s - loss: 0.5347 - accuracy: 0.8240
# Epoch 2: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 63s 49ms/step - loss: 0.5347 - accuracy: 0.8240 - val_loss: 0.5210 - val_accuracy: 0.8314
# Epoch 3/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.3274 - accuracy: 0.8922
# Epoch 3: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 62s 48ms/step - loss: 0.3273 - accuracy: 0.8922 - val_loss: 0.4540 - val_accuracy: 0.8534
# Epoch 4/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.2202 - accuracy: 0.9273
# Epoch 4: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 62s 48ms/step - loss: 0.2202 - accuracy: 0.9273 - val_loss: 0.4522 - val_accuracy: 0.8636
# Epoch 5/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.1556 - accuracy: 0.9480
# Epoch 5: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 62s 48ms/step - loss: 0.1556 - accuracy: 0.9480 - val_loss: 0.4847 - val_accuracy: 0.8628
# Epoch 6/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.1180 - accuracy: 0.9605
# Epoch 6: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 63s 48ms/step - loss: 0.1180 - accuracy: 0.9606 - val_loss: 0.4482 - val_accuracy: 0.8838
# Epoch 7/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.0996 - accuracy: 0.9664
# Epoch 7: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 62s 48ms/step - loss: 0.0996 - accuracy: 0.9664 - val_loss: 0.4069 - val_accuracy: 0.8930
# Epoch 8/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.1039 - accuracy: 0.9650
# Epoch 8: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 64s 49ms/step - loss: 0.1039 - accuracy: 0.9650 - val_loss: 0.4579 - val_accuracy: 0.8827
# Epoch 9/10
# 1302/1302 [==============================] - ETA: 0s - loss: 0.0512 - accuracy: 0.9837
# Epoch 9: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 66s 51ms/step - loss: 0.0512 - accuracy: 0.9837 - val_loss: 0.4000 - val_accuracy: 0.9067
# Epoch 10/10
# 1301/1302 [============================>.] - ETA: 0s - loss: 0.0570 - accuracy: 0.9817
# Epoch 10: saving model to ./training/20220406-164906/fold4/checkpoints\cp.ckpt
# 1302/1302 [==============================] - 63s 48ms/step - loss: 0.0571 - accuracy: 0.9817 - val_loss: 0.4690 - val_accuracy: 0.8920
# INFO:tensorflow:Assets written to: ./training/20220406-164906/fold4/model.hd5\assets
# 1980/1980 - 15s - loss: 3.3963 - accuracy: 0.4979 - 15s/epoch - 7ms/step
# Epoch 1/10
#    1310/Unknown - 88s 63ms/step - loss: 1.1137 - accuracy: 0.6136
# Epoch 1: saving model to ./training/20220406-170059/fold5/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 104s 76ms/step - loss: 1.1137 - accuracy: 0.6136 - val_loss: 0.6296 - val_accuracy: 0.7914
# Epoch 2/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.4989 - accuracy: 0.8385
# Epoch 2: saving model to ./training/20220406-170059/fold5/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 63s 48ms/step - loss: 0.4989 - accuracy: 0.8385 - val_loss: 0.5205 - val_accuracy: 0.8319
# Epoch 3/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.9095
# Epoch 3: saving model to ./training/20220406-170059/fold5/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 67s 51ms/step - loss: 0.2819 - accuracy: 0.9095 - val_loss: 0.4780 - val_accuracy: 0.8488
# Epoch 4/10
# 1310/1310 [==============================] - ETA: 0s - loss: 0.1802 - accuracy: 0.9410
# Epoch 4: saving model to ./training/20220406-170059/fold5/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 65s 50ms/step - loss: 0.1802 - accuracy: 0.9410 - val_loss: 0.8128 - val_accuracy: 0.8078
# Epoch 5/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.1325 - accuracy: 0.9555
# Epoch 5: saving model to ./training/20220406-170059/fold5/checkpoints\cp.ckpt
# 1310/1310 [==============================] - 64s 49ms/step - loss: 0.1324 - accuracy: 0.9555 - val_loss: 0.4376 - val_accuracy: 0.8789
# Epoch 6/10
# 1309/1310 [============================>.] - ETA: 0s - loss: 0.0983 - accuracy: 0.9678
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7604\4043882081.py in <module>
#      37
#      38     # Fit model
# ---> 39     yamnet_model.fit(train_dataset, validation_data = eval_dataset, epochs=10,
#      40         verbose=1, callbacks=[cp_callback,tensorboard_callback])
#      41
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1418                 model=self,
#    1419                 steps_per_execution=self._steps_per_execution)
# -> 1420           val_logs = self.evaluate(
#    1421               x=val_x,
#    1422               y=val_y,
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\keras\engine\training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1714             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1715               callbacks.on_test_batch_begin(step)
# -> 1716               tmp_logs = self.test_function(iterator)
#    1717               if data_handler.should_sync:
#    1718                 context.async_wait()
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2954       (graph_function,
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2956     return graph_function._call_flat(
#    2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1851         and executing_eagerly):
#    1852       # No tape is watching; skip to running the function.
# -> 1853       return self._build_call_outputs(self._inference_function.call(
#    1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     497       with _InterpolateFunctionError(self):
#     498         if cancellation_manager is None:
# --> 499           outputs = execute.execute(
#     500               str(self.signature.name),
#     501               num_outputs=self._num_outputs,
#
# C:\ProgramData\Miniconda3\envs\usc39\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52   try:
#      53     ctx.ensure_initialized()
# ---> 54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
